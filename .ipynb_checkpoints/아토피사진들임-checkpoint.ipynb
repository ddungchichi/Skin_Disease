# %%
# !pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
import urllib.request
from urllib.error import HTTPError

# %%
service = Service(executable_path = "chromedriver.exe")
driver = webdriver.Chrome()
driver.get("http://www.google.co.kr/imghp?h1=ko&ogb1")

input_element = driver.find_element(By.CLASS_NAME, "gLFyf")
input_element.send_keys("Atopy skin" + Keys.ENTER)

scd = driver.find_element(By.TAG_NAME, 'body')
for i in range(60):
    scd.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)

try:
    view_more_button = webDriverWait(driver, 10).until(EC.element_to_be_clickable((By.CALSS_NAME, 'mye4qd')))
    view_more_button.click()
    for i in range(80):
        scd.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.1)
except:
    pass

images = driver.find_elements(By.CSS_SELECTOR, ".YQ4gaf")
links = [image.get_attribute('src') for image in images if image.get_attribute('src') is not None]
print('찾은 이미지의 개수 : ', len(links))

for k, i in enumerate(links):
    url = i
    try:
        # 다운로드할 경로 지정
        folder_path = r'C:\Users\yohee\SkinDisease_AI\아토피3'

        # 폴더가 존재하지 않으면 생성
        if not os.path.exists(folder_path):
            os.makedirs(folder_path)

        # 이미지 저장 경로
        download_path = os.path.join(folder_path, str(k) + '.jpg')

        # 이미지 다운로드
        urllib.request.urlretrieve(url, download_path)
        print(f"다운로드 완료: {download_path}")
    except HTTPError as e:
        print(f"Error {e.code}: {url} 파일을 찾을 수 없습니다.")
    except Exception as e:
        print(f"다른 오류 발생: {str(e)}")
# Out:
# 찾은 이미지의 개수 :  1065
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\0.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\1.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\2.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\3.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\4.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\5.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\6.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\7.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\8.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\9.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\10.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\11.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\12.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\13.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\14.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\15.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\16.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\17.jpg
# 다운로드 완료: C:\Users\yohee\SkinDisease_AI\아토피\18.jpg
# ...
